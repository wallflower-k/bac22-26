# %% [markdown]
# #### Задача 1.
#
# Сделаем вид, что мы не знаем про существование таких библиотек, как numpy, и напишем свой собственный модуль, в котором будут собраны несколько функций для работы с матрицами. Матрицы будем представлять себе в виде списка списков. В нашем модуле должны содержаться следующие функции:
#
#     def printmatrix(matrix):
#         """Функция красиво выводит в печать матрицу: с выравниванием"""
#
#     def generaterandommatrix(m, n, min=0, max=10):
#         """Функция генерирует матрицу размера MxN со случайными числами в диапазоне от min до max"""
#
#     def zeromatrix(m, n):
#         """Функция генерирует нулевую матрицу размера MxN"""
#
#     def identitymatrix(n):
#         """Функция генерирует единичную матрицу размера n (единичная матрица бывает только квадратной)"""
#
#     def summatrices(m1, m2):
#         """Функция складывает матрицы. Не забудьте проверить их размеры"""
#
#     def multmatrices(m1, m2):
#         """Функция умножает матрицы (погуглите, как правильно это делать, и не забудьте про проверки размеров матриц)"""
#
#     def transpose(matrix):
#         """Функция транспонирует матрицу"""
#
# Модуль надо будет написать в .py, загрузить в колаб и импортировать его, а в качестве теста повызывать написанные функции.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Для обработки текстовых документов формата .docx (Microsoft Word) существует библиотека python-docx. Установите ее, самостоятельно разберитесь в ее документации на сайте pypi.org и напишите скрипт, который будет принимать путь к файлу .docx, считывать оттуда текст, оставлять в тексте только слова без пунктуации и подсчитывать, сколько в документе было слов. За реализацию этого скрипта в классах +1 балл.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Дополним нашу библиотеку для docx-файлов модулем pdfminer.six: это очень простой модуль, который умеет считывать pdf (но только если они оптически распознаны...). Установите его и напишите скрипт, который будет принимать файлы либо в docx, либо в pdf и пытаться конвертировать их в текстовые. Предусмотрите возможность того, что человек передал несуществующий путь к файлу или у файла оказалось не поддерживаемое расширение (например, jpg).

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Для красивого цветного вывода (как для Colab, так и для py-скриптов) существует две библиотеки: colorama и termcolor. В Visual Studio Code и ipynb-тетрадках скорее будет работать termcolor, но может не сработать, правда; в py-скриптах скорее будет работать colorama. Попробуйте обе, разберитесь, как они работают, и дополните код для задачи 2 таким образом, чтобы вывод был цветным (ошибка красным, сообщение об удачной конвертации - зеленым).

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Все, конечно, пользовались Google Translate? Для того, чтобы получать к нему доступ прямо из питона, есть библиотека googletrans. Правда, у нее есть некоторые проблемы... попробуйте с ними самостоятельно разобраться (погуглите способы решения: они точно есть, и в большом количестве). Напишите программу, которая будет принимать текст на каком-нибудь языке и переводить его на другой язык (с языками - какие хотите, главное, которые есть в GT).

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Библиотека Pillow используется для работы с изображениями. Помимо того, что она умеет их редактировать (может обрезать, повернуть, изменить масштаб или применить фильтры), также с ее помощью можно конвертировать форматы изображений. Разберитесь с документацией и напишите простенький конвертер картинок, который будет уметь переводить картинки форматов ico, png, jpg и webp.

# %%
# your code here

# %% [markdown]
# #### Задача 7.
#
# Библиотека argparse - стандартная библиотека, которая позволяет парсить аргументы прямо из командной строки. Почитайте в документации, как это сделать, и добавьте для нашего конвертера возможность принимать из командной строки путь к файлу/папке, тип желаемого формата для конвертации, возможность удалять исходные изображения или оставлять их.

# %%
# code it in .py

# %% [markdown]
# #### Задача 8 (на несколько человек).
#
# Давайте совместно напишем небольшую игру в ООП: за основу возьмем типичные d&d-игры, в которых персонаж определенного класса (воин, волшебник, вор...) бродит по карте и дерется с монстрами, находит всякие ништяки и разговаривает с дружественными нпц. Очевидно, нам понадобится много классов: совместно подумайте над тем, как нам спланировать такую игру, какую иерархию классов написать и - главное - по каким модулям их распределить. Потом можно по очереди начинать писать эти классы, ну и не забудьте про главный класс Game, который бы запускал всю игрушку и предлагал игроку выбор действий и т.п.
#
# Тестировать можно в колабе, загружая туда py-модули.

# %%
# code it in .py
