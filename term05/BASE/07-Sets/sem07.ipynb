# %% [markdown]
# ### Примеры

# %% [markdown]
# #### Задача 1.
#
# Посчитайте количество уникальных слов в тексте.

# %%
# my code here

# %% [markdown]
# #### Задача 2.
#
# Соберите множество кириллических букв.

# %%
# my code here

# %% [markdown]
# #### Задача 3.
#
# Пользователь в цикле по одному вводит какие-то слова, пока не введет "стоп". Программа должна сообщать, если слово уже вводилось.

# %%
# my code here

# %% [markdown]
# ### Задачи

# %% [markdown]
# #### Задача 1.
#
# Даны два списка чисел. Найдите все числа, которые входят как в первый, так и во второй список, и выведите их в порядке возрастания.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Напишите функцию, которая будет считать лексическое разнообразие текста. Лексическое разнообразие - это отношение количества уникальных слов к общему количеству слов (для красоты пусть будет в процентах и с округлением до двух знаков после запятой).

# %%
def lex_div(text):
  # your code here

text = '''Наси-горенг (индон. и малайск. nasi goreng, буквально — «жареный рис») — блюдо ряда национальных кухонь Юго-Восточной Азии, прежде всего — индонезийской. Представляет собой обжаренную в растительном масле смесь риса с измельчёнными продуктами животного или растительного происхождения. По мнению большинства специалистов, технология приготовления этого кушанья была заимствована в середине нашей эры из китайской кухни.
Несмотря на внешнее сходство со многими блюдами из риса, широко известными на Западе — пловом, паэльей, ризотто, джамбалайей, — наси-горенг существенно отличается от них в плане кулинарной технологии — прежде всего тем, что для его приготовления используется уже варёный, а не сырой рис.
Блюдо имеет множество вариаций в плане используемых продуктов и приправ. Особой популярностью оно пользуется на Яве, где исторически является одним из главных кулинарных специалитетов. В яванской и ряде других региональных кухонь Индонезии порция наси-горенга часто дополняется традиционным комплексным гарниром, в который обычно входят яичница или омлет, крупук, небольшое количество свежих или мочёных овощей, несколько шпажек миниатюрного шашлыка сате и, иногда, какие-то другие закуски. Кроме того, в некоторых районах Явы иногда практикуется смешение наси-горенга с другими кушаньями, в частности, с различными видами лапши.
Помимо Индонезии, блюдо получило весьма широкое распространение в Малайзии, Сингапуре и Брунее, а также определённую популярность за пределами Юго-Восточной Азии — прежде всего, в Нидерландах. При этом на международном уровне оно воспринимается преимущественно как «кулинарный символ» именно Индонезии.'''

lex_div(text)

# %% [markdown]
# #### Задача 3.
#
# Доработайте функцию с проверкой, является ли строка кириллической, с использованием множеств. Можно ли обойтись без циклов?

# %%
def iscyrillic(string):
  # your code here

# %% [markdown]
# #### Задача 4.
#
# Поиграем в города. Программа в цикле получает какие-то названия городов и проверяет, что предыдущее название заканчивалось на букву, на которую начинается введенное, а если такое название уже было, то сообщает об этом. Например:
#
#     Москва
#     Анапа
#     Антверпен
#     Норильск
#     Сочи - не на ту букву!
#     Курск
#     Краснодар
#     Рим
#     Москва - уже вводилось!

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Студенты решили собрать списки всех языков, какие они знают. Сперва программе сообщается общее число студентов, потом каждый студент вводит количество языков, которые знает, и сами эти языки один за другим на отдельной строчке. Программа должна вывести список языков, которые знает хотя бы один студент, и список языков, которые знают все студенты, например:
#
#     Студентов: 3
#     Языков: 3
#     английский
#     французский
#     немецкий
#     Языков: 2
#     английский
#     испанский
#     Языков: 4
#     английский
#     турецкий
#     корейский
#     немецкий
#
#     Языки, которые знает хотя бы один студент: английский, французский, немецкий, испанский, турецкий, корейский
#     Языки, которые знают все студенты: английский

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# На онлайн-экзамене есть 20 билетов и 80 студентов. Необходимо написать программу, которая поможет экзаменатору раздавать билеты так, чтобы уже взятые билеты по истечении некоторого времени возвращались в общую стопку и могли быть взяты больше одного раза, но не два раза подряд. Экзаменатор решил поступить следующим образом: откладывать взятые билеты в отдельную стопочку, а когда количество их в этой стопочке станет больше 10, по одному возвращать в общую стопку.
#
# В программе, следовательно, должно быть множество всех билетов, откуда студенты тянут билет (на каждом следующем студенте программа выводит их номера, из которых студенты могут выбирать), выбранный студентом билет извлекается из этого множества и отправляется в отдельный список уже взятых. Как только количество взятых билетов достигает 10, на каждом следующем студенте один билет (самый давно взятый) возвращается для выбора.

# %%
# your code here

# %% [markdown]
# #### Задача 7.
#
# Вы капитан школьной команды по киберспорту и вам нужно выбрать игроков для турнира. Ваша задача — составить уникальную команду из лучших игроков, используя списки и множества.
#
# **Условия**:
# 1. У вас есть два списка игроков:
#    - results_list — содержит игроков, отобранных по результатам тренировок.
#    - recommendations_list — содержит игроков, которых посоветовали ваши товарищи.
#
# 2. Каждый игрок в списках записан в формате строки с именем.
#
# 3. Ваша команда должна состоять только из уникальных игроков (то есть без повторов), и максимальный размер команды — 5 человек.
#
# 4. Если игроков больше, чем нужно, отберите первых 5 по алфавиту.
#
# 5. Если какой-то игрок уже состоит в вашей команде, его добавлять не нужно.
#
# Напишите функцию gather_team(results_list, recommendations_list, team), которая:
#
# - Принимает два списка и множество team (игроки, уже состоящие в вашей команде).
# - Возвращает обновленную команду в виде множества.
#
# **Пример работы функции**:
#
#     results_list = ["Андрей", "Света", "Маша", "Игорь", "Дима"]
#     recommendations_list = ["Игорь", "Катя", "Антон", "Света"]
#     team = {"Алексей"}
#
#     new_team = gather_team(results_list, recommendations_list, team)
#     print(new_team)
#
# **Ожидаемый результат**:
#
#     ['Алексей', 'Андрей', 'Антон', 'Дима', 'Игорь']
#
#
# **Подсказки**:
#
# - Используйте множества для удаления повторов.
# - Воспользуйтесь методом .union() для объединения игроков.
# - Не забудьте про сортировку и ограничение размера команды.

# %%
# your code here

# %% [markdown]
# #### Задача 8.
#
# На складе потерянных вещей хранятся предметы, которые пассажиры оставили в транспорте. Ваша задача — разработать систему учета, которая поможет сотрудникам находить, добавлять и убирать предметы.
#
# **Условия**:
#
# 1. На складе уже есть некоторые предметы, представленные в виде списка *warehouse*.
# 2. Сотрудники каждый день приносят новые находки, представленные в списке *new_findings*.
# 3. Иногда пассажиры забирают свои вещи, поэтому есть список *returned_things*.
#
# Напишите функцию renew_warehouse(warehouse, new_findings, returned_things), которая:
#
# - Добавляет в склад все новые находки.
# - Убирает из склада возвращенные вещи.
# - Возвращает обновленный склад в виде множества.
#
# **Пример работы функции**:
#
#     warehouse = ["зонтик", "рюкзак", "книга", "шарф"]
#     new_findings = ["перчатки", "зонтик", "телефон"]
#     returned_things = ["книга", "шарф"]
#
#     renewed_warehouse = renew_warehouse(warehouse, new_findings, returned_things)
#     print(renewed_warehouse)
#
# **Ожидаемый результат**:
#
#     ['зонтик', 'рюкзак', 'перчатки', 'зонтик', 'телефон']

# %%
# your code here

# %% [markdown]
# #### Задача 9.
#
# Вы устраиваете вечеринку и хотите, чтобы все гости чувствовали себя комфортно. Поэтому нужно составить список приглашенных так, чтобы:
# - Не было повторов (никого не звали дважды).
# - Гости не пересекались с соседней вечеринкой, которая проходит в тот же день.
#
# **Условия**:
#
# 1. Есть список ваших гостей: my_guests.
# 2. Есть список гостей из соседней вечеринки: neighbour_guests.
# 3. Вам нужно составить список приглашенных на вашу вечеринку:
#    - Убрать из вашего списка гостей тех, кто уже приглашен на соседнюю вечеринку.
#    - Вернуть итоговый список в алфавитном порядке.
#
# Напишите функцию make_list(my_guests, neighbour_guests), которая:
#
# - Принимает два списка.
# - Возвращает отсортированный список гостей, которые точно придут только к вам.
#
# **Пример работы функции**:
#
#     my_guests = ["Аня", "Борис", "Вика", "Глеб", "Даша"]
#     neighbour_guests = ["Вика", "Глеб", "Катя"]
#
#     result_list = make_list(my_guests, neighbour_guests)
#     print(result_list)
#
# **Ожидаемый результат**:
#
#     ['Аня', 'Борис', 'Даша']
#
# **Подсказки**:
#
# - Преобразуйте списки в множества, чтобы быстро находить разницу.
# - Используйте .difference() для исключения гостей из соседней вечеринки.
# - Не забудьте вернуть итоговый список в алфавитном порядке с помощью функции sorted().

# %%
# your code here
